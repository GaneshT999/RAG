# %% [markdown]
# ### Data Ingestion

# %%
###Document Structure

from  langchain_core.documents import Document
# Out:
# c:\Users\tgane\Documents\projects\AI\RAG\.venv\Lib\site-packages\langchain_core\_api\deprecation.py:25: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1.fields import FieldInfo as FieldInfoV1

# %%
doc = Document(
    page_content="This is the main text content I am using to create RAG",
    metadata={
        "source": "example.txt",
        "author": "Ganesh Talluri",
        "date": "2024-06-01"
    }
)

# %%
## Create a simple txt file 
import os
os.makedirs("../data/text_files", exist_ok=True)

# %%
sample_text = {
    "../data/text_files/python_intro.txt": """This is the main text content I am using to create RAG
    genterate random text about retrieval augmented generation 
   Python 
   1. Python is a high-level programming language.
    2. It is widely used for web development, data analysis, artificial intelligence, and more.
    3. Python has a large standard library and a vibrant ecosystem of third-party packages.
    4. It is known for its readability and simplicity, making it a popular choice for beginners and experienced developers alike.
"""
}
for file_path, content in sample_text.items():
    with open(file_path, "w") as f:
        f.write(content)
print("Sample text files created successfully.")
# Out:
# Sample text files created successfully.

# %%
### TextLoader
from langchain_community.document_loaders import TextLoader

loader = TextLoader("../data/text_files/python_intro.txt", encoding="utf-8")
document = loader.load()
print(document)
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='This is the main text content I am using to create RAG\n    genterate random text about retrieval augmented generation \n   Python \n   1. Python is a high-level programming language.\n    2. It is widely used for web development, data analysis, artificial intelligence, and more.\n    3. Python has a large standard library and a vibrant ecosystem of third-party packages.\n    4. It is known for its readability and simplicity, making it a popular choice for beginners and experienced developers alike.\n')]

# %%
### DirectoryLoader
from langchain_community.document_loaders import DirectoryLoader
directory_loader = DirectoryLoader("../data/text_files", glob="**/*.txt",
                                   loader_cls=TextLoader,loader_kwargs={"encoding": "utf-8"}, show_progress=False )
documents = directory_loader.load()
print(documents)
# Out:
# [Document(metadata={'source': '..\\data\\text_files\\python_intro.txt'}, page_content='This is the main text content I am using to create RAG\n    genterate random text about retrieval augmented generation \n   Python \n   1. Python is a high-level programming language.\n    2. It is widely used for web development, data analysis, artificial intelligence, and more.\n    3. Python has a large standard library and a vibrant ecosystem of third-party packages.\n    4. It is known for its readability and simplicity, making it a popular choice for beginners and experienced developers alike.\n')]

# %%
from langchain_community.document_loaders import PyMuPDFLoader, PyPDFLoader 
directory_loader = DirectoryLoader("../data/pdf_files", glob="**/*.pdf",
                                   loader_cls=PyMuPDFLoader, show_progress=False )
pdf_documents = directory_loader.load()
pdf_documents
# Out:
# [Document(metadata={'producer': 'Mac OS X 10.9.1 Quartz PDFContext', 'creator': 'Adobe Illustrator CC (Macintosh)', 'creationdate': "D:20140224195805Z00'00'", 'source': '..\\data\\pdf_files\\git-cheat-sheet.pdf', 'file_path': '..\\data\\pdf_files\\git-cheat-sheet.pdf', 'total_pages': 2, 'format': 'PDF 1.3', 'title': 'git-cheat-sheet-education', 'author': '', 'subject': '', 'keywords': '', 'moddate': "D:20140224195805Z00'00'", 'trapped': '', 'modDate': "D:20140224195805Z00'00'", 'creationDate': "D:20140224195805Z00'00'", 'page': 0}, page_content="GIT CHEAT SHEET\nSTAGE & SNAPSHOT\nWorking with snapshots and the Git staging area\ngit status\nshow modiﬁed ﬁles in working directory, staged for your next commit\ngit add [file]\nadd a ﬁle as it looks now to your next commit (stage)\ngit reset [file]\nunstage a ﬁle while retaining the changes in working directory\ngit diff\ndiﬀ of what is changed but not staged\ngit diff --staged\ndiﬀ of what is staged but not yet committed\ngit commit -m “
# ...
